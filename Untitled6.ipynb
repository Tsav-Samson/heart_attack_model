# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:/Users/PRESTIGE PC/Pictures/CAS/heart_failure_clinical_records_dataset.csv')

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.head(20)
# Out:
#      age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0   75.0        0                       582         0                 20
# 1   55.0        0                      7861         0                 38
# 2   65.0        0                       146         0                 20
# 3   50.0        1                       111         0                 20
# 4   65.0        1                       160         1                 20
# 5   90.0        1                        47         0                 40
# 6   75.0        1                       246         0                 15
# 7   60.0        1                       315         1                 60
# 8   65.0        0                       157         0                 65
# 9   80.0        1                       123         0                 35
# 10  75.0        1                        81         0                 38
# 11  62.0        0                       231         0                 25
# ...

# %%
df.tail(20)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 279  55.0        0                        84         1                 38
# 280  70.0        0                      2695         1                 40
# 281  70.0        0                       582         0                 40
# 282  42.0        0                        64         0                 30
# 283  65.0        0                      1688         0                 38
# 284  50.0        1                        54         0                 40
# 285  55.0        1                       170         1                 40
# 286  60.0        0                       253         0                 35
# 287  45.0        0                       582         1                 55
# 288  65.0        0                       892         1                 35
# 289  90.0        1                       337         0                 38
# 290  45.0        0                       615         1                 55
# ...

# %%
len(df.columns)
# Out:
# 13

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# Length: 299, dtype: bool

# %%
print('Shape of the dataset', df.shape)
# Out:
# Shape of the dataset (299, 13)

# %%
"""Checking the number of unique values in each column"""
dict = {}
for i in list(df.columns):
    dict[i] = df[i].value_counts().shape[0]
    
pd.DataFrame(dict, index =['unique count']).transpose()
# Out:
#                           unique count
# age                                 47
# anaemia                              2
# creatinine_phosphokinase           208
# diabetes                             2
# ejection_fraction                   17
# high_blood_pressure                  2
# platelets                          176
# serum_creatinine                    40
# serum_sodium                        27
# sex                                  2
# smoking                              2
# time                               148
# DEATH_EVENT                          2

# %%
"""Separating the columns in categorical and contineous"""
cat_cols = ['sex', 'anaemia', 'diabetes', 'high_blood_pressure', 'smoking']
con_cols = ['time', 'serum_sodium', 'platelets', 'creatinine_phosphokinase', 'age', 'ejection_fraction', 'serum_creatinine']
target_col = ['DEATH_EVENT']
print('The categorical cols are: ', cat_cols)
print('The continuous cols are: ', con_cols)
print('The target variable is: ', target_col)
# Out:
# The categorical cols are:  ['sex', 'anaemia', 'diabetes', 'high_blood_pressure', 'smoking']
# The continuous cols are:  ['time', 'serum_sodium', 'platelets', 'creatinine_phosphokinase', 'age', 'ejection_fraction', 'serum_creatinine']
# The target variable is:  ['DEATH_EVENT']

# %%
# summary statistics for the categorical column include
df[cat_cols].describe().transpose()
# Out:
#                      count      mean       std  min  25%  50%  75%  max
# sex                  299.0  0.648829  0.478136  0.0  0.0  1.0  1.0  1.0
# anaemia              299.0  0.431438  0.496107  0.0  0.0  0.0  1.0  1.0
# diabetes             299.0  0.418060  0.494067  0.0  0.0  0.0  1.0  1.0
# high_blood_pressure  299.0  0.351171  0.478136  0.0  0.0  0.0  1.0  1.0
# smoking              299.0  0.321070  0.467670  0.0  0.0  0.0  1.0  1.0

# %%
# summary statistics for the continuous column include
df[con_cols].describe().transpose()
# Out:
#                           count           mean           std      min  \
# time                      299.0     130.260870     77.614208      4.0
# serum_sodium              299.0     136.625418      4.412477    113.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# age                       299.0      60.833893     11.894809     40.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
#
#                                25%       50%       75%       max
# time                          73.0     115.0     203.0     285.0
# serum_sodium                 134.0     137.0     140.0     148.0
# platelets                 212500.0  262000.0  303500.0  850000.0
# creatinine_phosphokinase     116.5     250.0     582.0    7861.0
# age                           51.0      60.0      70.0      95.0
# ...

# %%
for key in df.keys():
    print(key, end= " ")
    print(df[key].max(), end = " ")
    print(df[key].min(), end = " ")
# Out:
# age 95.0 40.0 anaemia 1 0 creatinine_phosphokinase 7861 23 diabetes 1 0 ejection_fraction 80 14 high_blood_pressure 1 0 platelets 850000.0 25100.0 serum_creatinine 9.4 0.5 serum_sodium 148 113 sex 1 0 smoking 1 0 time 285 4 DEATH_EVENT 1 0

# %%
# checking for missing values
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
"""Count plot of categorical features"""
fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(2,3)
gs.update(wspace = 0.5, hspace = 0.15)
ax0 = fig.add_subplot(gs[0,0])
ax1 = fig.add_subplot(gs[0,1])
ax2 = fig.add_subplot(gs[0,2])
ax3 = fig.add_subplot(gs[1,0])
ax4 = fig.add_subplot(gs[1,1])
ax5 = fig.add_subplot(gs[1,2])


background_color = "#ffe6e6"
color_palette = ["#800000", "#8000ff", "#6aac90", "#5833ff", "#da8829"]
fig.patch.set_facecolor(background_color)
ax0.set_facecolor(background_color)
ax1.set_facecolor(background_color)
ax2.set_facecolor(background_color)
ax3.set_facecolor(background_color)
ax4.set_facecolor(background_color)
ax5.set_facecolor(background_color)


"""Title of the plot"""
ax0.spines['bottom'].set_visible(False)
ax0.spines['left'].set_visible(False)
ax0.spines['top'].set_visible(False)
ax0.spines['right'].set_visible(False)
ax0.tick_params(left = False, bottom = False)
ax0.set_xticklabels([])
ax0.set_yticklabels([])
ax0.text(0.5, 0.5, 'Count plot for various \n categorical features\n_______________', horizontalalignment='center', verticalalignment='center',fontsize = 18, fontweight = 'bold',  fontfamily ='serif', color = '#000000')


#Sex count
ax1.text(0.3, 210, 'Sex', fontsize= 14, fontweight='bold', fontfamily = 'serif', color="#000000")
ax1.grid(color ='#000000', linestyle = ':', axis ='y', zorder=0, dashes=(1, 5))
sns.countplot(ax = ax1, data = df, x ='sex', palette=color_palette)
ax1.set_xlabel("")
ax1.set_ylabel("")

#Anaemia count
ax2.text(0.3, 180, 'Anaemia', fontsize= 14, fontweight='bold', fontfamily = 'serif', color="#000000")
ax2.grid(color ='#000000', linestyle = ':', axis ='y', zorder=0, dashes=(1, 5))
sns.countplot(ax = ax2, data = df, x ='anaemia', palette=color_palette)
ax2.set_xlabel("")
ax2.set_ylabel("")

#Diabetes count
ax3.text(0.5, 180, 'Diabetes', fontsize= 14, fontweight='bold', fontfamily = 'serif', color="#000000")
ax3.grid(color ='#000000', linestyle = ':', axis ='y', zorder=0, dashes=(1, 5))
sns.countplot(ax = ax3, data = df, x ='diabetes', palette=color_palette)
ax3.set_xlabel("")
ax3.set_ylabel("")

#HBP count
ax4.text(0.5, 210, 'High_blood_pressure', fontsize= 14, fontweight='bold', fontfamily = 'serif', color="#000000")
ax4.grid(color ='#000000', linestyle = ':', axis ='y', zorder=0, dashes=(1, 5))
sns.countplot(ax = ax4, data = df, x ='high_blood_pressure', palette=color_palette)
ax4.set_xlabel("")
ax4.set_ylabel("")


#Smoking count
ax5.text(0.75, 205, 'Smoking', fontsize= 14, fontweight='bold', fontfamily = 'serif', color="#000000")
ax5.grid(color ='#000000', linestyle = ':', axis ='y', zorder=0, dashes=(1, 5))
sns.countplot(ax = ax5, data = df, x ='smoking', palette=color_palette)
ax5.set_xlabel("")
ax5.set_ylabel("")



for s in ["top", "right", "left"]:
    ax1.spines[s].set_visible(False)
    ax2.spines[s].set_visible(False)
    ax3.spines[s].set_visible(False)
    ax4.spines[s].set_visible(False)
    ax5.spines[s].set_visible(False)

# %%
fig = plt.figure(figsize=(8, 8))
gs = fig.add_gridspec(4, 2)
gs.update(wspace=0.4, hspace =0.4)
ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[0, 1])
ax2 = fig.add_subplot(gs[1, 0])
ax3 = fig.add_subplot(gs[1, 1])
ax4 = fig.add_subplot(gs[2, 0])
ax5 = fig.add_subplot(gs[2, 1])
ax6 = fig.add_subplot(gs[3, 0])
ax7 = fig.add_subplot(gs[3, 1])

background_color = "#ffe6e6"
color_palette = ["#800000", "#8000ff", "#6aac90", "#5833ff", "#da8829", "#2268ff", "#ff0034"]
fig.patch.set_facecolor(background_color)
ax0.set_facecolor(background_color)
ax1.set_facecolor(background_color)
ax2.set_facecolor(background_color)
ax3.set_facecolor(background_color)
ax4.set_facecolor(background_color)
ax5.set_facecolor(background_color)

#Title of the plot spines
ax0.spines["bottom"].set_visible(False)
ax0.spines["left"].set_visible(False)
ax0.spines["top"].set_visible(False)
ax0.spines["right"].set_visible(False)
ax0.tick_params(left=False, bottom=False)
ax0.set_xticklabels([])
ax0.set_yticklabels([])
ax0.text(0.5, 0.5, 'Boxen plot for various \n continuous features \n---------------', horizontalalignment ='center', verticalalignment='center', fontsize = 18, fontweight= 'bold', fontfamily ='serif', color ="#000000")

#Time 
ax1.text(-0.45, 320, 'Time', fontsize = 14, fontweight = 'bold', fontfamily='serif', color="000000")
ax1.grid(color='#000000', linestyle=':', axis = 'y', zorder = 0, dashes=(1, 5))
sns.boxenplot(ax=ax1, y=df['time'], palette=["#800000"], width=0.6)
ax1.set_xlabel("")
ax1.set_ylabel("")

#Serum_sodium 
ax2.text(-0.45, 158, 'Serum_sodium', fontsize = 14, fontweight = 'bold', fontfamily='serif', color="000000")
ax2.grid(color='#000000', linestyle=':', axis = 'y', zorder = 0, dashes=(1, 5))
sns.boxenplot(ax=ax2, y=df['serum_sodium'], palette=["#8000ff"], width=0.6)
ax2.set_xlabel("")
ax2.set_ylabel("")

#Platelets
ax3.text(-0.45, 850000, 'platelets', fontsize = 14, fontweight = 'bold', fontfamily='serif', color="000000")
ax3.grid(color='#000000', linestyle=':', axis = 'y', zorder = 0, dashes=(1, 5))
sns.boxenplot(ax=ax3, y=df['platelets'], palette=["#6aac90"], width=0.6)
ax3.set_xlabel("")
ax3.set_ylabel("")

#Creatinine_phosphokinase
ax4.text(-0.79, 8500, 'Creatinine_phosphokinase', fontsize = 14, fontweight = 'bold', fontfamily='serif', color="000000")
ax4.grid(color='#000000', linestyle=':', axis = 'y', zorder = 0, dashes=(1, 5))
sns.boxenplot(ax=ax4, y=df['creatinine_phosphokinase'], palette=["#5833ff"], width=0.6)
ax4.set_xlabel("")
ax4.set_ylabel("")

#age
ax5.text(-0.45, 90, 'Age', fontsize = 14, fontweight = 'bold', fontfamily='serif', color="000000")
ax5.grid(color='#000000', linestyle=':', axis = 'y', zorder = 0, dashes=(1, 5))
sns.boxenplot(ax=ax5, y=df['age'], palette=["#da8829"], width=0.6)
ax5.set_xlabel("")
ax5.set_ylabel("")

# Ejection_fraction
ax6.text(-0.75, 90, 'Ejection_fraction', fontsize = 14, fontweight ='bold', fontfamily='serif', color='000000')
ax6.grid(color='#000000', linestyle=':', axis='y', zorder=0, dashes=(1, 5))
sns.boxenplot(ax=ax6, y=df['ejection_fraction'], palette=['#2258ff'])
ax6.set_xlabel("")
ax6.set_ylabel("")

# Serum_creatinine
ax7.text(-0.45, 10.6, 'Serum_creatinine', fontsize = 14, fontweight ='bold', fontfamily='serif', color='000000')
ax7.grid(color='#000000', linestyle=':', axis='y', zorder=0, dashes=(1, 5))
sns.boxenplot(ax=ax7, y=df['serum_creatinine'], palette=["#ff0034"])
ax7.set_xlabel("")
ax7.set_ylabel("")

for s in ["top", "right", "left"]:
    ax1.spines[s].set_visible(False)
    ax2.spines[s].set_visible(False)
    ax3.spines[s].set_visible(False)
    ax4.spines[s].set_visible(False)
    ax5.spines[s].set_visible(False)
    ax6.spines[s].set_visible(False)
    ax7.spines[s].set_visible(False)

# %%
# Count plot for output variable
fig = plt.figure(figsize=(18, 7))
gs = fig.add_gridspec(1,2)
gs.update(wspace=0.3, hspace =0.15)
ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[0, 1])

background_color ="#ffe6e6"
color_palette = ["#800000", "#8000ff", "#6aac98", "#5833ff", "#da8829"]
fig.patch.set_facecolor(background_color)
ax0.set_facecolor(background_color)
ax1.set_facecolor(background_color)

# Title of the plot
ax0.text(0.5, 0.5, "Count of the target \n --------", horizontalalignment='center', verticalalignment="center", fontsize= 14, fontweight='bold', fontfamily='serif', color='#000000')
ax0.set_xticklabels([])
ax0.set_yticklabels([])
ax0.tick_params(left =False, bottom=False)

# Target count
ax1.text(0.35, 220, "DEATH_EVENT", horizontalalignment='center', verticalalignment="center", fontsize= 14, fontweight='bold', fontfamily='serif', color='#000000')
ax1.grid(color='#000000', linestyle=':', axis='y', zorder=0, dashes=(1, 5))
sns.countplot(ax=ax1, data=df, x='DEATH_EVENT', palette=color_palette)
ax1.set_xlabel("")
ax1.set_ylabel("")
ax1.set_xticklabels(["Low chances of death(0)", "High chances of death(1)]"])

ax0.spines['top'].set_visible(False)
ax0.spines['right'].set_visible(False)
ax0.spines['bottom'].set_visible(False)
ax0.spines['left'].set_visible(False)

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)

# %%
# Bivariate analysis
# Correlation matrix of continuous features
df_corr = df[con_cols].corr().transpose()
df_corr
# Out:
#                               time  serum_sodium  platelets  \
# time                      1.000000      0.087640   0.010514
# serum_sodium              0.087640      1.000000   0.062125
# platelets                 0.010514      0.062125   1.000000
# creatinine_phosphokinase -0.009346      0.059550   0.024463
# age                      -0.224068     -0.045966  -0.052354
# ejection_fraction         0.041729      0.175902   0.072177
# serum_creatinine         -0.149315     -0.189095  -0.041198
#
#                           creatinine_phosphokinase       age  \
# time                                     -0.009346 -0.224068
# serum_sodium                              0.059550 -0.045966
# platelets                                 0.024463 -0.052354
# creatinine_phosphokinase                  1.000000 -0.081584
# age                                      -0.081584  1.000000
# ejection_fraction                        -0.044080  0.060098
# ...

# %%
fig = plt.figure(figsize=(10, 10))
gs = fig.add_gridspec(1, 1)
gs.update(wspace=0.3, hspace = 0.15)
ax0 = fig.add_subplot(gs[0, 0])

color_palette = ["#5833ff", "#da8829"]
mask = np.triu(np.ones_like(df_corr))
ax0.text(1.5, -0.1, "Correlation Matrix", fontfamily ='serif', color="#000000")
df_corr = df[con_cols].corr().transpose()
sns.heatmap(df_corr, mask=mask, fmt=".1f", annot=True, cmap='YlGnBu')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_axis = df['age']
y_axis = df['DEATH_EVENT']
plt.barh(x_axis, y_axis)
plt.show()

# %%
# visualising the customer type 
# Member = 0
# Normal = 1
x = (df['DEATH_EVENT']==0).sum()
y= (df['DEATH_EVENT']==1).sum()
total = np.array([x, y])
print(total)
mylabels = ['NOT DEAD', 'DEAD']
myexplode = [0.2, 0]
plt.pie(x = total, labels = mylabels,colors=['#ff3568','#aafc67'],explode=myexplode, autopct='%1.1f%%')
plt.legend(bbox_to_anchor=(1.3, 1.4))
# Out:
# [203  96]

# %%
keys =[]
for key in df.keys():
    if key != 'DEATH_EVENT':
        keys.append(key)
print(keys)
# Out:
# ['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes', 'ejection_fraction', 'high_blood_pressure', 'platelets', 'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score


X = df.drop('DEATH_EVENT', axis=1).values
y = df.drop(keys, axis = 1).values

# splitting the features
scores = []
kf = KFold(n_splits = 10, shuffle = True)
splits = list(kf.split(X))

for train_index, test_index in splits:
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    model = LogisticRegression()
    model.fit(X_train, y_train)
    scores.append(model.score(X_test, y_test))

    #taking the mean of the accuracy scores    
print(np.mean(scores))
# Out:
# 0.8096551724137931

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
# print('X_train', X_train)
# print('X_test', X_test)

# %%
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)
y_pred = final_model.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.76

# %%
# print(y_pred)

# %%
# print(y_test.reshape(1,-1))

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[45  8]
#  [10 12]]

# %%
print('Accuracy', accuracy_score(y_test, y_pred))
# Out:
# Accuracy 0.76

# %%
print('recall', recall_score(y_test, y_pred))
# Out:
# recall 0.5454545454545454

# %%
print('precision', precision_score(y_test, y_pred))
# Out:
# precision 0.6

# %%
print('f1_score', f1_score(y_test, y_pred))
# Out:
# f1_score 0.5714285714285713

# %%
# implementing a Random Forest classifier
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 42)
rf_model.fit(X_train, y_train)

# make predictions
yhat = rf_model.predict(X_test)

# %%
# Evaluating the random forest model's performance 
accuracy = accuracy_score(y_test, yhat)
print(accuracy)
# Out:
# 0.8

# %%
print(confusion_matrix(y_test, yhat))
# Out:
# [[46  7]
#  [ 8 14]]

# %%
# Decision tree algorithm implementation
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, y_train)

# make predictions
y_cap = dt_model.predict(X_test)

# %%
# Evaluating the model's performance 
accuracy = accuracy_score(y_test, y_cap)
print(accuracy)
# Out:
# 0.64

# %%
print(confusion_matrix(y_test, y_cap))
# Out:
# [[41 12]
#  [11 11]]
